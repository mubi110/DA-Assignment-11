# %%
import pandas as pd
import sqlite3 as sql

# %%
conn = sql.connect('database.sqlite')
conn

# %%
q = 'select * from sqlite_master'
q
# Out:
# 'select * from sqlite_master'

# %%
df = pd.read_sql_query(q,conn)
df
# Out:
#     type               name  tbl_name  rootpage  \
# 0  table           Salaries  Salaries         2
# 1  index  salaries_year_idx  Salaries     16566
#
#                                                  sql
# 0  CREATE TABLE Salaries (\n    Id INTEGER PRIMAR...
# 1  CREATE INDEX salaries_year_idx ON Salaries (Year)

# %%
df['sql'].loc[0]
# Out:
# 'CREATE TABLE Salaries (\n    Id INTEGER PRIMARY KEY,\n    EmployeeName TEXT,\n    JobTitle TEXT,\n    BasePay NUMERIC,\n    OvertimePay NUMERIC,\n    OtherPay NUMERIC,\n    Benefits NUMERIC,\n    TotalPay NUMERIC,\n    TotalPayBenefits NUMERIC,\n    Year INTEGER,\n    Notes TEXT,\n    Agency TEXT,\n    Status TEXT)'

# %%
q = 'select * from salaries'
pd.read_sql_query(q,conn)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    184152.298
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
def sql_query(q):
    return pd.read_sql_query(q,conn)

# %%
q = 'select JobTitle from salaries'
read_sql_query(q)
# Out:
#                                               JobTitle
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                      CAPTAIN III (POLICE DEPARTMENT)
# 2                      CAPTAIN III (POLICE DEPARTMENT)
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                                                ...
# 148649                                       Custodian
# 148650                                    Not provided
# 148651                                    Not provided
# 148652                                    Not provided
# 148653                      Counselor, Log Cabin Ranch
#
# [148654 rows x 1 columns]

# %%
q = 'select JobTitle,OvertimePay from salaries'
sql_query(q)
# Out:
#                                               JobTitle   OvertimePay
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY             0
# 1                      CAPTAIN III (POLICE DEPARTMENT)     245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)     106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC      56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)          9737
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
# [148654 rows x 2 columns]

# %%
q = 'select * from salaries'
df1 = sql_query(q)
df1
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    184152.298
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
q = '''select EmployeeName,TotalPayBenefits from salaries 
    where employeename = 'Joe Lopez' or employeename = 'Roy I Tillery'
'''
sql_query(q)
# Out:
#     EmployeeName  TotalPayBenefits
# 0  Roy I Tillery          25467.88
# 1  Roy I Tillery              0.00
# 2      Joe Lopez           -618.13

# %%
q = '''select * from salaries
    where TotalPay > 50000 and year == 2011
'''
sql_query(q)
# Out:
#           Id       EmployeeName  \
# 0          1     NATHANIEL FORD
# 1          2       GARY JIMENEZ
# 2          3     ALBERT PARDINI
# 3          4  CHRISTOPHER CHONG
# 4          5    PATRICK GARDNER
# ...      ...                ...
# 24695  24696         LI JING XI
# 24696  24697          THAI TIEU
# 24697  24698      EVERT SARAVIA
# 24698  24699       ERICK DAIGLE
# 24699  24700          ALEX DURU
#
#                                              JobTitle     BasePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  184152.298
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.020
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.130
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.000
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.600
# ...                                               ...         ...
# 24695                                           CLERK   46387.410
# ...

# %%
q = '''select * from salaries
    where TotalPay between 50000 and 150000
'''
sql_query(q)
# Out:
#            Id        EmployeeName  \
# 0        2220           JAY DOWKE
# 1        2221         MURRAY BOND
# 2        2222         MARILOU GAN
# 3        2223       BRIAN COLLINS
# 4        2224        GREGORY NEAL
# ...       ...                 ...
# 90786  138428     Stephanie Reidy
# 90787  138429  Maria Theresa Luna
# 90788  138480      Paul E Maltzer
# 90789  138491       Kevin I Dolar
# 90790  138525   Kathleen N Yumang
#
#                                            JobTitle    BasePay  OvertimePay  \
# 0                                POLICE OFFICER III  112380.37     15463.96
# 1      MANAGER VI - MUNICIPAL TRANSPORTATION AGENCY  164973.38         0.00
# 2                                  REGISTERED NURSE  119703.78      8791.20
# 3                                       FIREFIGHTER  105934.65     26506.04
# 4                                  POLICE OFFICER I   106065.2     14306.42
# ...                                             ...        ...          ...
# ...

# %%
q = '''select * from salaries
    where TotalPay in(335279.91,567595.43)
'''
sql_query(q)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   3  ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
#
#       BasePay  OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  184152.298         0.00  400184.25           567595.43         567595.43
# 1  212739.130    106088.18   16452.60           335279.91         335279.91
#
#    Year Notes         Agency Status
# 0  2011        San Francisco
# 1  2011        San Francisco

# %%
q = '''select * from salaries
    where TotalPay not in(335279.91,567595.43)
'''
sql_query(q)
# Out:
#             Id       EmployeeName  \
# 0            2       GARY JIMENEZ
# 1            4  CHRISTOPHER CHONG
# 2            5    PATRICK GARDNER
# 3            6     DAVID SULLIVAN
# 4            7          ALSON LEE
# ...        ...                ...
# 148647  148650      Roy I Tillery
# 148648  148651       Not provided
# 148649  148652       Not provided
# 148650  148653       Not provided
# 148651  148654          Joe Lopez
#
#                                             JobTitle       BasePay  \
# 0                    CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 1               WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 2       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# 3                          ASSISTANT DEPUTY CHIEF II        118602
# 4                 BATTALION CHIEF, (FIRE DEPARTMENT)      92492.01
# ...                                              ...           ...
# 148647                                     Custodian             0
# ...

# %%
df1
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    184152.298
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
q = 'select count(*) from salaries'
sql_query(q)
# Out:
#    count(*)
# 0    148654

# %%
q = 'select min(BasePay) from salaries'
sql_query(q)
# Out:
#    min(BasePay)
# 0       -166.01

# %%
q = 'select max(BasePay) from salaries'
sql_query(q)
# Out:
#    max(BasePay)
# 0  Not Provided

# %%
q ='select avg(BasePay) from salaries'
sql_query(q)
# Out:
#    avg(BasePay)
# 0  66385.169541

# %%
q = 'select distinct(Jobtitle) from salaries'
sql_query(q)
# Out:
#                                             JobTitle
# 0     GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                    CAPTAIN III (POLICE DEPARTMENT)
# 2               WIRE ROPE CABLE MAINTENANCE MECHANIC
# 3       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 4                          ASSISTANT DEPUTY CHIEF II
# ...                                              ...
# 2154                    Sr Cnselor, Juv Hall (SFERS)
# 2155                  Forensic Toxicologist Supervis
# 2156                                      Conversion
# 2157                                       Cashier 3
# 2158                                    Not provided
#
# [2159 rows x 1 columns]

# %%
q = '''select distinct(Jobtitle) from salaries
    where JobTitle != 'Not provided'
'''
sql_query(q)
# Out:
#                                             JobTitle
# 0     GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                    CAPTAIN III (POLICE DEPARTMENT)
# 2               WIRE ROPE CABLE MAINTENANCE MECHANIC
# 3       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 4                          ASSISTANT DEPUTY CHIEF II
# ...                                              ...
# 2153                        Marina Associate Manager
# 2154                    Sr Cnselor, Juv Hall (SFERS)
# 2155                  Forensic Toxicologist Supervis
# 2156                                      Conversion
# 2157                                       Cashier 3
#
# [2158 rows x 1 columns]
