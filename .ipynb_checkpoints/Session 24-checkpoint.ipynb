# %%
import pandas as pd
import sqlite3 as sql

# %%
dir(sql)
# Out:
# ['Binary',
#  'Blob',
#  'Connection',
#  'Cursor',
#  'DataError',
#  'DatabaseError',
#  'Date',
#  'DateFromTicks',
#  'Error',
#  'IntegrityError',
#  'InterfaceError',
#  'InternalError',
#  'LEGACY_TRANSACTION_CONTROL',
#  'NotSupportedError',
#  'OperationalError',
#  'PARSE_COLNAMES',
#  'PARSE_DECLTYPES',
#  'PrepareProtocol',
#  'ProgrammingError',
#  'Row',
#  'SQLITE_ABORT',
#  'SQLITE_ABORT_ROLLBACK',
#  'SQLITE_ALTER_TABLE',
#  'SQLITE_ANALYZE',
#  'SQLITE_ATTACH',
#  'SQLITE_AUTH',
#  'SQLITE_AUTH_USER',
#  'SQLITE_BUSY',
#  'SQLITE_BUSY_RECOVERY',
#  'SQLITE_BUSY_SNAPSHOT',
#  'SQLITE_BUSY_TIMEOUT',
#  'SQLITE_CANTOPEN',
#  'SQLITE_CANTOPEN_CONVPATH',
#  'SQLITE_CANTOPEN_DIRTYWAL',
#  'SQLITE_CANTOPEN_FULLPATH',
#  'SQLITE_CANTOPEN_ISDIR',
#  'SQLITE_CANTOPEN_NOTEMPDIR',
#  'SQLITE_CANTOPEN_SYMLINK',
#  'SQLITE_CONSTRAINT',
#  'SQLITE_CONSTRAINT_CHECK',
#  'SQLITE_CONSTRAINT_COMMITHOOK',
#  'SQLITE_CONSTRAINT_FOREIGNKEY',
#  'SQLITE_CONSTRAINT_FUNCTION',
# ...

# %%
conn = sql.connect('database.sqlite')
conn

# %%
q = 'select * from sqlite_master'
q
# Out:
# 'select * from sqlite_master'

# %%
df = pd.read_sql_query(q,conn)
df
# Out:
#     type               name  tbl_name  rootpage  \
# 0  table           Salaries  Salaries         2
# 1  index  salaries_year_idx  Salaries     16566
#
#                                                  sql
# 0  CREATE TABLE Salaries (\n    Id INTEGER PRIMAR...
# 1  CREATE INDEX salaries_year_idx ON Salaries (Year)

# %%
df['sql']
# Out:
# 0    CREATE TABLE Salaries (\n    Id INTEGER PRIMAR...
# 1    CREATE INDEX salaries_year_idx ON Salaries (Year)
# Name: sql, dtype: object

# %%
df['sql'].loc[0]
# Out:
# 'CREATE TABLE Salaries (\n    Id INTEGER PRIMARY KEY,\n    EmployeeName TEXT,\n    JobTitle TEXT,\n    BasePay NUMERIC,\n    OvertimePay NUMERIC,\n    OtherPay NUMERIC,\n    Benefits NUMERIC,\n    TotalPay NUMERIC,\n    TotalPayBenefits NUMERIC,\n    Year INTEGER,\n    Notes TEXT,\n    Agency TEXT,\n    Status TEXT)'

# %%
df.sql
# Out:
# 0    CREATE TABLE Salaries (\n    Id INTEGER PRIMAR...
# 1    CREATE INDEX salaries_year_idx ON Salaries (Year)
# Name: sql, dtype: object

# %%
q = 'select * from salaries'
pd.read_sql_query(q,conn)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    184152.298
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
q = 'select jobtitle from salaries'
pd.read_sql_query(q,conn)
# Out:
#                                               JobTitle
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                      CAPTAIN III (POLICE DEPARTMENT)
# 2                      CAPTAIN III (POLICE DEPARTMENT)
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                                                ...
# 148649                                       Custodian
# 148650                                    Not provided
# 148651                                    Not provided
# 148652                                    Not provided
# 148653                      Counselor, Log Cabin Ranch
#
# [148654 rows x 1 columns]

# %%
q = 'select jobtitle,totalpay from salaries'
pd.read_sql_query(q,conn)
# Out:
#                                               JobTitle   TotalPay
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  567595.43
# 1                      CAPTAIN III (POLICE DEPARTMENT)  538909.28
# 2                      CAPTAIN III (POLICE DEPARTMENT)  335279.91
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC  332343.61
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  326373.19
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# 148650                                    Not provided       0.00
# 148651                                    Not provided       0.00
# 148652                                    Not provided       0.00
# 148653                      Counselor, Log Cabin Ranch    -618.13
#
# [148654 rows x 2 columns]

# %%
def sql_query(q):
   return pd.read_sql_query(q,conn)

# %%
sql_query(q)
# Out:
#                                               JobTitle   TotalPay
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  567595.43
# 1                      CAPTAIN III (POLICE DEPARTMENT)  538909.28
# 2                      CAPTAIN III (POLICE DEPARTMENT)  335279.91
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC  332343.61
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  326373.19
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# 148650                                    Not provided       0.00
# 148651                                    Not provided       0.00
# 148652                                    Not provided       0.00
# 148653                      Counselor, Log Cabin Ranch    -618.13
#
# [148654 rows x 2 columns]

# %%
q = 'select * from salaries'

# %%
df1 = sql_query(q)
df1
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    184152.298
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
q = '''select * from salaries
    where EmployeeName  == 'ALBERT PARDINI'  
'''
sql_query(q)
# Out:
#    Id    EmployeeName                         JobTitle    BasePay  \
# 0   3  ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13
#
#    OvertimePay  OtherPay Benefits   TotalPay  TotalPayBenefits  Year Notes  \
# 0    106088.18   16452.6           335279.91         335279.91  2011
#
#           Agency Status
# 0  San Francisco

# %%
q = '''select jobtitle from salaries
    where EmployeeName  == 'ALBERT PARDINI'  
'''
sql_query(q)
# Out:
#                           JobTitle
# 0  CAPTAIN III (POLICE DEPARTMENT)

# %%
df1
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    184152.298
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
q = '''select * from salaries
    where EmployeeName  == 'ALBERT PARDINI' and EmployeeName  == 'CHRISTOPHER CHONG'
'''
sql_query(q)
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
q = '''select * from salaries
    where EmployeeName  == 'ALBERT PARDINI' or EmployeeName  == 'CHRISTOPHER CHONG'
'''
sql_query(q)
# Out:
#    Id       EmployeeName                              JobTitle    BasePay  \
# 0   3     ALBERT PARDINI       CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 1   4  CHRISTOPHER CHONG  WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
#
#    OvertimePay  OtherPay Benefits   TotalPay  TotalPayBenefits  Year Notes  \
# 0    106088.18   16452.6           335279.91         335279.91  2011
# 1     56120.71  198306.9           332343.61         332343.61  2011
#
#           Agency Status
# 0  San Francisco
# 1  San Francisco

# %%
q = """select * from salaries
    where totalpay > 50000 and year == 2011

"""
sql_query(q)
# Out:
#           Id       EmployeeName  \
# 0          1     NATHANIEL FORD
# 1          2       GARY JIMENEZ
# 2          3     ALBERT PARDINI
# 3          4  CHRISTOPHER CHONG
# 4          5    PATRICK GARDNER
# ...      ...                ...
# 24695  24696         LI JING XI
# 24696  24697          THAI TIEU
# 24697  24698      EVERT SARAVIA
# 24698  24699       ERICK DAIGLE
# 24699  24700          ALEX DURU
#
#                                              JobTitle     BasePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  184152.298
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.020
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.130
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.000
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.600
# ...                                               ...         ...
# 24695                                           CLERK   46387.410
# ...

# %%
q = '''select * from salaries
    where totalpay between 20000 and 50000

'''
sql_query(q)
# Out:
#            Id      EmployeeName                       JobTitle   BasePay  \
# 0       24701  GORAN MARJANOVIC                       GARDENER   49339.6
# 1       24702       JAMES PHUNG                   SENIOR CLERK  48705.84
# 2       24703     JONELLE CHASE         OCCUPATIONAL THERAPIST  49980.52
# 3       24704      APRIL PIERCE             SPEECH PATHOLOGIST  49980.04
# 4       24705     HECTOR MINIMO                         PORTER   48472.4
# ...       ...               ...                            ...       ...
# 17850  141804    Kristen Bailey                  Special Nurse  17253.47
# 17851  141805    Eric M Bongato          X-Ray Laboratory Aide   20000.5
# 17852  141815     Boris Reynish                      Custodian  18378.98
# 17853  141837       Jingyan Liu  Respiratory Care Practitioner  20053.45
# 17854  141840    Benson B Chhan                   Museum Guard  19877.79
#
#        OvertimePay  OtherPay Benefits  TotalPay  TotalPayBenefits  Year Notes  \
# ...

# %%
q = '''select * from salaries
    where totalpay in(20053.45,49980.04)

'''
sql_query(q)
# Out:
#        Id  EmployeeName                       JobTitle   BasePay  OvertimePay  \
# 0   24704  APRIL PIERCE             SPEECH PATHOLOGIST  49980.04            0
# 1  141837   Jingyan Liu  Respiratory Care Practitioner  20053.45            0
#
#    OtherPay Benefits  TotalPay  TotalPayBenefits  Year Notes         Agency  \
# 0         0           49980.04          49980.04  2011        San Francisco
# 1         0        0  20053.45          20053.45  2014        San Francisco
#
#   Status
# 0
# 1     PT

# %%
q = '''select * from salaries
    where totalpay not in(20053.45,49980.04)

'''
sql_query(q)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148647  148650      Roy I Tillery
# 148648  148651       Not provided
# 148649  148652       Not provided
# 148650  148653       Not provided
# 148651  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    184152.298
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
q = '''select * from salaries
    where totalpay not between 20000 and 50000

'''
sql_query(q)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 130794  148650      Roy I Tillery
# 130795  148651       Not provided
# 130796  148652       Not provided
# 130797  148653       Not provided
# 130798  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    184152.298
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
q = 'select count(*) from salaries'
sql_query(q)
# Out:
#    count(*)
# 0    148654

# %%
q = 'select count(*) as Count from salaries'
sql_query(q)
# Out:
#     Count
# 0  148654

# %%
q = 'select min(totalpay) from salaries'
sql_query(q)
# Out:
#    min(totalpay)
# 0        -618.13

# %%
q = 'select max(totalpay) as max totalpay from salaries'
sql_query(q)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# OperationalError: near "totalpay": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[81], line 2
#       1 q = 'select max(totalpay) as max totalpay from salaries'
# ----> 2 sql_query(q)
#
# Cell In[33], line 2, in sql_query(q)
#       1 def sql_query(q):
# ----> 2    return pd.read_sql_query(q,conn)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
# ...

# %%
q = 'select max(totalpay) as max_totalpay from salaries'
sql_query(q)
# Out:
#    max_totalpay
# 0     567595.43

# %%
q = 'select max(totalpay) as "max totalpay" from salaries'
sql_query(q)
# Out:
#    max totalpay
# 0     567595.43

# %%
q = 'select max(totalpay) as (max totalpay) from salaries'
sql_query(q)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# OperationalError: near "(": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[87], line 2
#       1 q = 'select max(totalpay) as (max totalpay) from salaries'
# ----> 2 sql_query(q)
#
# Cell In[33], line 2, in sql_query(q)
#       1 def sql_query(q):
# ----> 2    return pd.read_sql_query(q,conn)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
# ...

# %%
q = 'select min(*) from salaries'
sql_query(q)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# OperationalError: wrong number of arguments to function min()
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[89], line 2
#       1 q = 'select min(*) from salaries'
# ----> 2 sql_query(q)
#
# Cell In[33], line 2, in sql_query(q)
#       1 def sql_query(q):
# ----> 2    return pd.read_sql_query(q,conn)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
# ...

# %%
q = 'select avg(totalpay) as Avg_TotalPay from salaries'
sql_query(q)
# Out:
#    Avg_TotalPay
# 0  74768.321972

# %%
df1
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    184152.298
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
q = 'select distinct jobtitle from salaries'
sql_query(q)
# Out:
#                                             JobTitle
# 0     GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                    CAPTAIN III (POLICE DEPARTMENT)
# 2               WIRE ROPE CABLE MAINTENANCE MECHANIC
# 3       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 4                          ASSISTANT DEPUTY CHIEF II
# ...                                              ...
# 2154                    Sr Cnselor, Juv Hall (SFERS)
# 2155                  Forensic Toxicologist Supervis
# 2156                                      Conversion
# 2157                                       Cashier 3
# 2158                                    Not provided
#
# [2159 rows x 1 columns]

# %%
q = 'select distinct(jobtitle) from salaries'
sql_query(q)
# Out:
#                                             JobTitle
# 0     GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                    CAPTAIN III (POLICE DEPARTMENT)
# 2               WIRE ROPE CABLE MAINTENANCE MECHANIC
# 3       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 4                          ASSISTANT DEPUTY CHIEF II
# ...                                              ...
# 2154                    Sr Cnselor, Juv Hall (SFERS)
# 2155                  Forensic Toxicologist Supervis
# 2156                                      Conversion
# 2157                                       Cashier 3
# 2158                                    Not provided
#
# [2159 rows x 1 columns]
